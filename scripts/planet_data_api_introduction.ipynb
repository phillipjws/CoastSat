# %% [markdown]
# # Planet Data API Introduction using Python
#
# ---

# %% [markdown]
# ## Introduction
#
# ---
#
# This tutorial is an introduction to [Planet](https://www.planet.com)'s Data API. It provides code samples on how to write simple Python code to access data.
#
# [`https://api.planet.com/data/v1`](https://api.planet.com/data/v1)
#
# The focus of this tutorial will be the search portion of the Planet Data API. We will find and download imagery data using complex searches and save them for later use, as well as learn how to get stats on search results. After completing this tutorial, you should feel comfortable interacting with the Data API, and have a good foundation for leveraging the Planet Data API for your own applications.

# %% [markdown]
# ## Table of Contents
#
# ---
#
# * **Introduction**
#     * Requirements
#        * Software & Modules
#        * Planet API Key
#     * Useful Links
#
#
# * **Overview**
#      * The Basic Workflow
#       * Data API Endpoints
#       * Planet Explorer
#
#
# * **Basic Setup**
#     * Authentication
#     * Helper Modules and Functions
#     * Our First Request
#
#
# * **Search Mechanics & Filters**
#     * Statistics
#     * Using a Search Filter
#     * Filter types
#         * Field Filters
#         * Logical Filters
#         * (Field) Filter Type examples
#     * Complex Queries using Logical Filters
#
#
# * **Searching for Items**
#     * Quick Search
#         * Mapping Footprints Example
#
#
# * **Assets & Permissions**
#     * Activating Assets
#     * Downloading Assets
#     * Rate Limits
#
#
# * **Saved Searches**
#
#
# * **Conclusion**

# %% [markdown]
# ### Requirements
#
# ---
#
# #### Software & Modules
#
# This tutorial assumes familiarity with the [Python](https://python.org) programming language throughout. Familiarity with basic REST API concepts and usage is also assumed.
#
# We'll be using a **"Jupyter Notebook"** (aka Python Notebook) to run through the examples.
# To learn more about and get started with using Jupyter, visit: [Jupyter](https://jupyter.org/) and [IPython](https://ipython.org/).
#
# For the best experience, download this notebook and run it on your system, and make sure to install the modules listed below first. You can also copy the examples' code to a separate Python files an run them directly with Python on your system if you prefer.
#
#
# Python modules used in this tutorial are:
# * [requests](http://docs.python-requests.org/)
# * [geojsonio](https://pypi.python.org/pypi/geojsonio)
#
#
# #### Planet API Key
#
# You should have an account on the Planet Platform to access the Data API. You may retrieve your API key from your [account page](https://www.planet.com/account/), or from the "API Tab" in [Planet Explorer](https://www.planet.com/explorer).

# %% [markdown]
# ### Useful links
#
# ---
#
# * [Planet Data API Reference & Documentation](https://developers.planet.com/docs/apis/data/)
# * [Planet Explorer](https://www.planet.com/explorer)

# %% [markdown]
# ## Overview
#
# ---
#
# ### The Basic Workflow:
#
# 1. Search item types based on filters
# 1. Activate assets
# 1. Download assets

# %% [markdown]
# ### API Endpoints
#
# This tutorial will cover the following API ***endpoints***:
#
# * [`/item-types`](https://api.planet.com/data/v1/item-types/)
# * [`/asset-types`](https://api.planet.com/data/v1/asset-types/)
# * `/quick-search`
# * `/searches`
# * `/stats`
#
# There is an additional [`/spec`](https://api.planet.com/data/v1/spec) endpoint that publishes a [Swagger](http://swagger.io/) specification for the Data API.
#
# ### Exploring Endpoints
#
# We can start by exploring two endpoints using our browser.
#
# ##### What item types are available?
#
# https://api.planet.com/data/v1/item-types/
#
# ##### What assets are available?
#
# https://api.planet.com/data/v1/asset-types/

# %% [markdown]
# ***Note:*** *You may choose to install a helpful browser plugin called **JSONView** that formats JSON and makes it easier to read:*
#
# * [Chrome Extension](https://chrome.google.com/webstore/detail/jsonview/chklaanhfefbnpoihckbnefhakgolnmc)
# * [Firefox Plugin](https://addons.mozilla.org/en-us/firefox/addon/jsonview/)

# %% [markdown]
# ### Planet Explorer
# We can also use Planet Explorer to expose relevant API information for search results.
#
# In Planet Explorer, while in *Daily Imagery Mode* click on the *"Api"* button in the bottom left corner of the results panel.
#
# ![Planet Explorer Screenshot](images/planet-explorer.png)
#
# Here, you may access your API Key, selected item id's, and `cURL` request information containing filters and options.

# %% [markdown]
# ## Basic Setup
#
# ---
#
# Before interacting with the Planet Data API using Python, we will set up our environment with some useful modules and helper functions.
#
# * We'll configure *authentication* to the Planet Data API
# * We'll use the `requests` Python module to make HTTP communication easier.
# * We'll use the `json` Python module to help us work with JSON responses from the API.
# * We'll create a function called `p` that will print Python dictionaries nicely.
#
# Then we'll be ready to make our first call to the Planet API by hitting the base endpoint at `https://api.planet.com/data/v1`.
#
# Let's start by importing needed packages configuring authentication:

# %% [markdown]
# ### Import Packages & Define Helper Functions

# %%
import os
import json
import requests
import geojsonio
import time
from dotenv import load_dotenv

load_dotenv()


# Helper function to printformatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# ### Authentication
#
# Authentication with the Planet Data API be achieved using a valid Planet **API key**.

# %% [markdown]
# You can *export* your API Key as an environment variable on your system:
#
# `export API_KEY="YOUR API KEY HERE"`
#
# Or add the variable to your path, etc. If you are using our Docker environement, it will already be set.
#
# To start our Python code, we'll setup an API Key variable from an environment variable to use with our requests:

# %%
# if your Planet API Key is not set as an environment variable, you can paste it below
API_KEY = os.getenv('PL_API_KEY')


    # construct auth tuple for use in the requests library
BASIC_AUTH = (API_KEY, '')

# %% [markdown]
# ### Our First Request

# %%
# Setup Planet Data API base URL
URL = "https://api.planet.com/data/v1"

# Setup the session
session = requests.Session()

# Authenticate
session.auth = (API_KEY, "")

# %%
# Make a GET request to the Planet Data API
res = session.get(URL)

# %% [markdown]
# Now we should get a response, hopefully it's a `200` code, saying everything is OK!

# %%
# Response status code
res.status_code
# Out:
# 200

# %%
# Response Body
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
# Print formatted JSON response
p(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
# Print the value of the item-types key from _links
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %% [markdown]
# **Congratulations!** You just made your first request to the Planet Data API using Python!
#
# Now, let's take a look at how to access all that high cadence satellite imagery!

# %% [markdown]
# ## Search Mechanics & Filters
#
# ---
#
# There's a lot of data available on the Planet Data API and in order to find what we're looking for, we'll have to perform various types of searches.
#
# To construct a search, we use **filters** that let us limit results based on date, geography or other metadata properties.
#
# Using these filters, we are able to **search** for items or get **statistics** for search results.
#
# Let's first make a request to the `/stats` endpoint to understand how the filters work:

# %% [markdown]
# ### Statistics `/stats`
#
# ---
#
# The `/stats` endpoint provides a summary of the available data based on some search criteria.
#
# `https://api.planet.com/data/v1/stats`
#
# We'll need to send a ***`POST`*** request to `/stats`, let's start by setting up the request url:

# %%
# Setup the stats URL
stats_url = "{}/stats".format(URL)

# Print the stats URL
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# ### Using a Search Filter
#
# Search filters should have the following properties:
#
# * **Type** (`type`) - The type of filter being used
# * **Configuration** (`config`) - The configuration for this filter
# * **Field Name** (`field_name`) - The field on which to filter
#
# For this example, let's use a filter to get some stats on what data is available for *Planet Scope (3 Band)* and *Rapid Eye (Ortho Tile)* products taken from 2013 until now:

# %%
# Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %% [markdown]
# Depending on the filter type, some requests may need an `interval` field:
#
# The following intervals are possible:
# * `year`
# * `month`
# * `week`
# * `day`
# * `hour`
#
# An `interval` must be provided with the request so that the number of matching items can be aggregated. We'll use an interval with our date filter.

# %% [markdown]
# Now let's perform our request using the `date_filter` filter we created above:

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 3113814,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3609128,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8604808,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 42043527,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 217199161,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 289342157,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 242641951,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 236425894,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 219034712,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 122895159,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 115838794,
#       "start_time": "2023-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 125412661,
#       "start_time": "2024-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 16284126,
#       "start_time": "2025-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ***Good Job!*** You've received a response from the API that contains some statistics like item counts for the search criteria!

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new date filter to find data from before 2013.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "lte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter2
}

res = session.post(stats_url, json=request)
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1353609,
#       "start_time": "2009-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 2153888,
#       "start_time": "2010-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 2493280,
#       "start_time": "2011-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 2716482,
#       "start_time": "2012-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ---
#
# Next, let's take a closer look at some of the available filters:

# %% [markdown]
# ### Filter types
#
# The Planet Data API supports several filter types. The most common are the following:
#
# ### Field Filters
#
# * `DateRangeFilter`
# * `RangeFilter`
# * `StringInFilter`
# * `PermissionFilter`
# * `GeometryFilter`
#
# ### Logical Filters
#
# * `NotFilter`
# * `AndFilter`
# * `OrFilter`
#
# More information and examples on filter types can be found at the [API Docs](https://developers.planet.com/docs/apis/).
#
# ---
#
# ### (Field) Filter Type examples:

# %% [markdown]
# #### `DateRangeFilter`
#
# Find imagery that was `acquired` or `published` before, after or between certain dates.
#
# ```
# {
#   "type": "DateRangeFilter",
#   "field_name": "acquired",
#   "config": {
#     "gt": "2016-01-01T00:00:00Z",
#     "lte": "2016-03-01T00:00:00Z"
#   }
# }
# ```
#
# The upper or lower bound may be omitted.

# %% [markdown]
# #### `RangeFilter`
#
# Find imagery that has a metadata that matches a number within a range of numbers.
#
# ```
# {
#   "type": "RangeFilter",
#   "field_name": "cloud_cover",
#   "config": {
#     "lt": 0.2,
#     "gt": 0.1
#   }
# }
# ```

# %% [markdown]
# The following **operators** are supported by the Data API's `DateRangeFilter` and `RangeFilter`:
# * `gt`: Greater Than
# * `gte`: Greater Than or Equal To
# * `lt`: Less Than
# * `lte`: Less Than or Equal To

# %% [markdown]
# #### `StringInFilter`
#
# Find imagery that has a metadata that matches a string within the array of provided strings.
#
#
# ```
# {
#   "type": "StringInFilter",
#   "field_name": "instrument",
#   "config": ["PS2"]
# }
# ```

# %% [markdown]
# #### `PermissionFilter`
#
# Find data which has assets that are accessible by the user.
#
# ```
# {
#   "type": "PermissionFilter",
#   "config": ["assets.analytic:download"]
# }
# ```
#
# ***Note:*** `assets:download` means *any* downloadable asset.

# %% [markdown]
# #### `GeometryFilter`
#
# Find data contained within a given geometry. The filter's config value may be any valid GeoJSON object.
#
# ```
# {
#   "type": "GeometryFilter",
#   "field_name": "geometry",
#   "config": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.74337300148126
#         ],
#         [
#           -119.761962890625,
#           38.348118547988065
#         ],
#         [
#           -120.27282714843749,
#           38.348118547988065
#         ]
#       ]
#     ]
#   }
# }
# ```
#
# A few quick ways to get a GeoJSON geometry to use in your search:
#
# * Draw an Area of Interst (AOI) in [Planet Explorer](http://planet.com/explorer), and use the API button to see the geometry filter config.
# * Use your favorite GIS tools like [Quantum GIS (QGIS)](http://www.qgis.org) and export GeoJSON.
# * Draw a polygon in [GeoJSON.io](http://geojson.io).
#
# Make sure the `config` property in the geometry filter is in the right format, which should be similar to a `feature` property in a GeoJSON object.

# %% [markdown]
# ---
#
# Let's try a few more requests and get some more stats, this time using different filters:

# %%
# Search for imagery only from PlanetScope satellites that have a PS2 telescope

# Setup item types
item_types = ["PSScene"]

# Setup a filter for instrument type
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1551072,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 34389763,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 213069535,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 286369397,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 212830341,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 192171605,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 137404041,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 22971208,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# <div class="alert alert-info">
#
# **Exercise:** Create a new filter that finds all data from PS0 or PS1 telescopes.
#
# </div>

# %%
# Fill in this filter to complete the exercise! 

instrument_filter2 = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS0", "PS1"]
}
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter2
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 466239,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3602217,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3872489,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 833,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Find a GeoJSON geometry from http://geojson.io and copy one `feature`.

# %%
# Search for imagery that only intersects with 40N, 90W

# Setup GeoJSON 
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup Geometry Filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : geometry_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 6,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 4,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 46,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 176,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 302,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 352,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 393,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 506,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 374,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 423,
#       "start_time": "2023-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 537,
#       "start_time": "2024-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 80,
#       "start_time": "2025-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# ### Complex Queries using Logical Filters
#
# Complex queries may require combining field filters using **logical filters** (see Filter Types above).
#
# Let's try a complex stats search:

# %%
# PS2 imagery; over 40N, 90W; captured between 2013 and present

# Setup an "AND" logical filter
and_filter = {
    "type": "AndFilter",
    "config": [instrument_filter, geometry_filter, date_filter]
}

# Print the logical filter
p(and_filter)
# Out:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "StringInFilter",
#       "field_name": "instrument",
#       "config": [
#         "PS2"
#       ]
#     },
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": {
#         "type": "Point",
#         "coordinates": [
#           -90,
#           40
#         ]
#       }
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2013-01-01T00:00:00.000Z"
#       }
#     }
#   ]
# }

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : and_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 1,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 45,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 176,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 302,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 253,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 204,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 147,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 25,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Here's another complex search query example using a "Not" logical filter and "string in" field filter. Can you tell what it's requesting?

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup Instrument Filter
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# Setup "not" Logical Filter
not_filter = {
    "type": "NotFilter",
    "config": instrument_filter
}

# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : not_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "buckets": [
#     {
#       "count": 466239,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3602217,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3872489,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 833,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 0,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 27134779,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 43906447,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 81630671,
#       "start_time": "2021-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 99923951,
#       "start_time": "2022-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 115838794,
#       "start_time": "2023-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 125412661,
#       "start_time": "2024-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 16284169,
#       "start_time": "2025-01-01T00:00:00.000000Z"
#     }
#   ],
#   "interval": "year",
#   "utc_offset": "+0h"
# }

# %% [markdown]
# Now that you're comfortable working with **filters**, let's take a look at how to perform searches!

# %% [markdown]
# ## Searching for Items
#
# ---
#
# There are two types of searches:
# * **"Quick Search"** `/quick-search`
# * **"Saved Searches"** `/searches`
#
# Saved searches are retained on the Planet Platform and may be performed again at any time in the future. You can use these to setup efficient workflows for repetitive tasks, for example, querying an area that is of interest to you, or getting data for specific sensors.
#
# Quick searches are meant to be more fleeting, and are not guaranteed to be available on the API after they are executed.
#
# Searches use the same request format as the `/stats` endpoint except without the `interval` field.

# %% [markdown]
# ### Quick Search
#
# Let's dive right in and create our first `quick search`:

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup GeoJSON for only imagery that intersects with 40N, 90W
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup a geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/78993033780a44b09faa342ada7b9443/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/78993033780a44b09faa342ada7b9443/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDI0LTA5LTExVDIwOjUwOjQ5LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjQwOTExXzE2NTkwMl8zNF8yNGZjIiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/78993033780a44b09faa342ada7b9443/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250227_162449_06_24a7",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250227_162449_06_24a7/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250227_162449_06_24a7/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.0795951561919,
#               40.06574328684943
#             ],
#             [
#               -90.12532616588742,
#               39.90866536701049
#             ],
#             [
#               -89.78224695287979,
#               39.84869734819396
#             ],
#             [
#               -89.73540349089957,
#               40.006378951838954
#             ],
#             [
#               -90.0795951561919,
#               40.06574328684943
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250227_162449_06_24a7",
#       "properties": {
#         "acquired": "2025-02-27T16:24:49.066623Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 96,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.4,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-27T21:44:30Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.6,
#         "satellite_id": "24a7",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7895422",
#         "sun_azimuth": 146,
#         "sun_elevation": 35.7,
#         "updated": "2025-02-28T05:32:10Z",
#         "view_angle": 4.6,
#         "visible_confidence_percent": 74,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250227_170519_78_2506",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250227_170519_78_2506/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250227_170519_78_2506/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.31836322748089,
#               40.07603657427107
#             ],
#             [
#               -90.36803786220845,
#               39.89942060980785
#             ],
#             [
#               -89.98465936346787,
#               39.83502326931333
#             ],
#             [
#               -89.93400459879668,
#               40.01103118201465
#             ],
#             [
#               -90.31836322748089,
#               40.07603657427107
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250227_170519_78_2506",
#       "properties": {
#         "acquired": "2025-02-27T17:05:19.788591Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 96,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-27T21:42:50Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 105.2,
#         "satellite_id": "2506",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7895219",
#         "sun_azimuth": 158.2,
#         "sun_elevation": 39.6,
#         "updated": "2025-02-28T05:57:30Z",
#         "view_angle": 1.8,
#         "visible_confidence_percent": 85,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250227_170517_51_2506",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250227_170517_51_2506/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250227_170517_51_2506/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.27760479211473,
#               40.21871714752194
#             ],
#             [
#               -90.3275459961983,
#               40.04213803418776
#             ],
#             [
#               -89.9433086013956,
#               39.97762145769689
#             ],
#             [
#               -89.89250771792047,
#               40.153707734967895
#             ],
#             [
#               -90.27760479211473,
#               40.21871714752194
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250227_170517_51_2506",
#       "properties": {
#         "acquired": "2025-02-27T17:05:17.518438Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 96,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-27T19:34:23Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 105.2,
#         "satellite_id": "2506",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7895219",
#         "sun_azimuth": 158.3,
#         "sun_elevation": 39.5,
#         "updated": "2025-02-28T05:57:29Z",
#         "view_angle": 1.8,
#         "visible_confidence_percent": 77,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250226_171618_87_2539",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250226_171618_87_2539/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250226_171618_87_2539/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.15402555027107,
#               40.15729319163387
#             ],
#             [
#               -90.2052545296585,
#               39.97483480701676
#             ],
#             [
#               -89.80711314648815,
#               39.90730147078359
#             ],
#             [
#               -89.7548207483812,
#               40.08940015871394
#             ],
#             [
#               -90.15402555027107,
#               40.15729319163387
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250226_171618_87_2539",
#       "properties": {
#         "acquired": "2025-02-26T17:16:18.875875Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 75,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-26T21:04:53Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 112.9,
#         "satellite_id": "2539",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7893032",
#         "sun_azimuth": 161.8,
#         "sun_elevation": 39.9,
#         "updated": "2025-02-27T04:07:50Z",
#         "view_angle": 0.7,
#         "visible_confidence_percent": 50,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250225_170545_45_24c6",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250225_170545_45_24c6/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250225_170545_45_24c6/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.13847383458285,
#               40.038107464622776
#             ],
#             [
#               -90.18695524594442,
#               39.867511193524074
#             ],
#             [
#               -89.81666430046211,
#               39.80462883369364
#             ],
#             [
#               -89.7674378476705,
#               39.97486935819035
#             ],
#             [
#               -90.13847383458285,
#               40.038107464622776
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250225_170545_45_24c6",
#       "properties": {
#         "acquired": "2025-02-25T17:05:45.454094Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 97,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-25T22:37:59Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 107.6,
#         "satellite_id": "24c6",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7890854",
#         "sun_azimuth": 158.7,
#         "sun_elevation": 38.9,
#         "updated": "2025-02-26T06:57:38Z",
#         "view_angle": 1.3,
#         "visible_confidence_percent": 97,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250225_170543_25_24c6",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250225_170543_25_24c6/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250225_170543_25_24c6/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.09921720924751,
#               40.176735298692975
#             ],
#             [
#               -90.14788008823439,
#               40.006142698355575
#             ],
#             [
#               -89.77687398427067,
#               39.94316876581292
#             ],
#             [
#               -89.72743166693311,
#               40.113410982419104
#             ],
#             [
#               -90.09921720924751,
#               40.176735298692975
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250225_170543_25_24c6",
#       "properties": {
#         "acquired": "2025-02-25T17:05:43.256481Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 97,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-25T22:37:58Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 107.6,
#         "satellite_id": "24c6",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7890854",
#         "sun_azimuth": 158.7,
#         "sun_elevation": 38.8,
#         "updated": "2025-02-26T09:57:51Z",
#         "view_angle": 1.3,
#         "visible_confidence_percent": 75,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250224_162501_96_24b2",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250224_162501_96_24b2/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250224_162501_96_24b2/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.17305117353179,
#               40.16835247440422
#             ],
#             [
#               -90.21519628084013,
#               40.01206636010028
#             ],
#             [
#               -89.87934296587756,
#               39.95707129287022
#             ],
#             [
#               -89.8366982880432,
#               40.11220028499249
#             ],
#             [
#               -90.17305117353179,
#               40.16835247440422
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250224_162501_96_24b2",
#       "properties": {
#         "acquired": "2025-02-24T16:25:01.963492Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 46,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.3,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-24T21:47:12Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 101.5,
#         "satellite_id": "24b2",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7888388",
#         "sun_azimuth": 147.3,
#         "sun_elevation": 35,
#         "updated": "2025-02-25T04:21:45Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 57,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250224_162503_93_24b2",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250224_162503_93_24b2/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250224_162503_93_24b2/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.208387736949,
#               40.04230456515884
#             ],
#             [
#               -90.25032913586132,
#               39.88593524924169
#             ],
#             [
#               -89.91555197001684,
#               39.83104792018253
#             ],
#             [
#               -89.87310834245804,
#               39.98625139626213
#             ],
#             [
#               -90.208387736949,
#               40.04230456515884
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250224_162503_93_24b2",
#       "properties": {
#         "acquired": "2025-02-24T16:25:03.932137Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 45,
#         "clear_percent": 0,
#         "cloud_cover": 1,
#         "cloud_percent": 100,
#         "ground_control": false,
#         "gsd": 3.3,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-24T21:45:54Z",
#         "publishing_stage": "preview",
#         "quality_category": "test",
#         "satellite_azimuth": 101.4,
#         "satellite_id": "24b2",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7888388",
#         "sun_azimuth": 147.3,
#         "sun_elevation": 35.1,
#         "updated": "2025-02-25T04:24:09Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 58,
#         "visible_percent": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250223_170526_06_251a",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250223_170526_06_251a/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250223_170526_06_251a/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.19613407302454,
#               40.120326719118246
#             ],
#             [
#               -90.24724124413997,
#               39.94422703813803
#             ],
#             [
#               -89.86392977604478,
#               39.87751801627107
#             ],
#             [
#               -89.81159517523471,
#               40.053856462222136
#             ],
#             [
#               -90.19613407302454,
#               40.120326719118246
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250223_170526_06_251a",
#       "properties": {
#         "acquired": "2025-02-23T17:05:26.06682Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 95,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-23T22:24:57Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 274.5,
#         "satellite_id": "251a",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7886213",
#         "sun_azimuth": 158.3,
#         "sun_elevation": 38,
#         "updated": "2025-02-24T09:57:09Z",
#         "view_angle": 2.3,
#         "visible_confidence_percent": 78,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250222_170616_76_24fb",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250222_170616_76_24fb/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250222_170616_76_24fb/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.22821123424667,
#               40.1238293046621
#             ],
#             [
#               -90.27694632318014,
#               39.953276886505606
#             ],
#             [
#               -89.90636925123685,
#               39.89017010707813
#             ],
#             [
#               -89.85691075209405,
#               40.060408170954396
#             ],
#             [
#               -90.22821123424667,
#               40.1238293046621
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250222_170616_76_24fb",
#       "properties": {
#         "acquired": "2025-02-22T17:06:16.767327Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 82,
#         "clear_percent": 95,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-22T22:59:51Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 117.5,
#         "satellite_id": "24fb",
#         "shadow_percent": 0,
#         "snow_ice_percent": 5,
#         "strip_id": "7883520",
#         "sun_azimuth": 158.9,
#         "sun_elevation": 37.8,
#         "updated": "2025-02-23T09:58:44Z",
#         "view_angle": 0.6,
#         "visible_confidence_percent": 60,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250221_170804_64_24ae",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250221_170804_64_24ae/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250221_170804_64_24ae/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.28802908767723,
#               40.07634931375774
#             ],
#             [
#               -90.33899354170038,
#               39.902171288316225
#             ],
#             [
#               -89.95812604843296,
#               39.835375837476604
#             ],
#             [
#               -89.9060474102021,
#               40.01038771311541
#             ],
#             [
#               -90.28802908767723,
#               40.07634931375774
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250221_170804_64_24ae",
#       "properties": {
#         "acquired": "2025-02-21T17:08:04.645997Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 69,
#         "clear_percent": 76,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 1,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-21T21:10:12Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 277.8,
#         "satellite_id": "24ae",
#         "shadow_percent": 0,
#         "snow_ice_percent": 23,
#         "strip_id": "7881159",
#         "sun_azimuth": 158.9,
#         "sun_elevation": 37.3,
#         "updated": "2025-02-22T04:57:38Z",
#         "view_angle": 4.6,
#         "visible_confidence_percent": 51,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250221_170802_39_24ae",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250221_170802_39_24ae/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250221_170802_39_24ae/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.24680477949364,
#               40.21809465592473
#             ],
#             [
#               -90.29780429287989,
#               40.04384356996644
#             ],
#             [
#               -89.91621546646282,
#               39.97702606119227
#             ],
#             [
#               -89.8638893510732,
#               40.15210835144973
#             ],
#             [
#               -90.24680477949364,
#               40.21809465592473
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250221_170802_39_24ae",
#       "properties": {
#         "acquired": "2025-02-21T17:08:02.391617Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 86,
#         "clear_percent": 93,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 1,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-21T21:09:40Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 277.7,
#         "satellite_id": "24ae",
#         "shadow_percent": 0,
#         "snow_ice_percent": 6,
#         "strip_id": "7881159",
#         "sun_azimuth": 159,
#         "sun_elevation": 37.2,
#         "updated": "2025-02-22T03:47:16Z",
#         "view_angle": 4.6,
#         "visible_confidence_percent": 61,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250220_170343_87_2409",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250220_170343_87_2409/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250220_170343_87_2409/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.26272478515315,
#               40.17325170026111
#             ],
#             [
#               -90.3123197808362,
#               39.99576593956028
#             ],
#             [
#               -89.92673721143947,
#               39.93177529039842
#             ],
#             [
#               -89.87629527770653,
#               40.10820449567446
#             ],
#             [
#               -90.26272478515315,
#               40.17325170026111
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250220_170343_87_2409",
#       "properties": {
#         "acquired": "2025-02-20T17:03:43.87976Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 72,
#         "clear_percent": 70,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.8,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-20T23:13:18Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 103.1,
#         "satellite_id": "2409",
#         "shadow_percent": 0,
#         "snow_ice_percent": 30,
#         "strip_id": "7879175",
#         "sun_azimuth": 158.6,
#         "sun_elevation": 36.9,
#         "updated": "2025-02-21T06:55:22Z",
#         "view_angle": 2.8,
#         "visible_confidence_percent": 59,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250219_170407_61_2523",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250219_170407_61_2523/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250219_170407_61_2523/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.22755839270366,
#               40.17937069659005
#             ],
#             [
#               -90.2770302362528,
#               40.00428621712249
#             ],
#             [
#               -89.8966314016468,
#               39.94049519543763
#             ],
#             [
#               -89.84644172359413,
#               40.11478562970099
#             ],
#             [
#               -90.22755839270366,
#               40.17937069659005
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250219_170407_61_2523",
#       "properties": {
#         "acquired": "2025-02-19T17:04:07.616271Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 62,
#         "clear_percent": 48,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.7,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 46,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-20T00:25:54Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 104.6,
#         "satellite_id": "2523",
#         "shadow_percent": 0,
#         "snow_ice_percent": 6,
#         "strip_id": "7876561",
#         "sun_azimuth": 158.7,
#         "sun_elevation": 36.5,
#         "updated": "2025-02-20T06:58:08Z",
#         "view_angle": 1.9,
#         "visible_confidence_percent": 61,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250218_170601_64_24aa",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250218_170601_64_24aa/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250218_170601_64_24aa/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.23552414171562,
#               40.15170947661554
#             ],
#             [
#               -90.28323896842247,
#               39.98438771400791
#             ],
#             [
#               -89.91996405109504,
#               39.922473857495255
#             ],
#             [
#               -89.87111206562507,
#               40.08930079910675
#             ],
#             [
#               -90.23552414171562,
#               40.15170947661554
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20250218_170601_64_24aa",
#       "properties": {
#         "acquired": "2025-02-18T17:06:01.641267Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 45,
#         "clear_percent": 0,
#         "cloud_cover": 0.01,
#         "cloud_percent": 1,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 99,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2025-02-18T19:35:22Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 123.5,
#         "satellite_id": "24aa",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7873713",
#         "sun_azimuth": 159.2,
#         "sun_elevation": 36.3,
#         "updated": "2025-02-19T03:46:47Z",
#         "view_angle": 0.4,
#         "visible_confidence_percent": 64,
#         "visible_percent": 99
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250217_170257_16_250d",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250217_170257_16_250d/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250217_170257_16_250d/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
# ...
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 277.8,
#         "satellite_id": "24c6",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7580108",
#         "sun_azimuth": 157.6,
#         "sun_elevation": 50.6,
#         "updated": "2024-09-16T09:05:19Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 83,
#         "visible_percent": 18
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240915_170103_40_24c6",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240915_170103_40_24c6/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240915_170103_40_24c6/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.15562367552076,
#               40.21856900522848
#             ],
#             [
#               -90.21037947502336,
#               40.03678307425212
#             ],
#             [
#               -89.81366725809045,
#               39.965918665168104
#             ],
#             [
#               -89.75728596528856,
#               40.14880730482608
#             ],
#             [
#               -90.15562367552076,
#               40.21856900522848
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240915_170103_40_24c6",
#       "properties": {
#         "acquired": "2024-09-15T17:01:03.407027Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 81,
#         "clear_percent": 0,
#         "cloud_cover": 0.97,
#         "cloud_percent": 97,
#         "ground_control": false,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 3,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-09-16T01:22:57Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 277.9,
#         "satellite_id": "24c6",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7580108",
#         "sun_azimuth": 157.7,
#         "sun_elevation": 50.4,
#         "updated": "2024-09-16T09:10:40Z",
#         "view_angle": 5,
#         "visible_confidence_percent": 78,
#         "visible_percent": 3
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240914_160734_98_24b2",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240914_160734_98_24b2/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240914_160734_98_24b2/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.08694053633923,
#               40.060770853938635
#             ],
#             [
#               -90.13331383927664,
#               39.89269490715219
#             ],
#             [
#               -89.76786039543114,
#               39.832764416665924
#             ],
#             [
#               -89.72070962821893,
#               39.99957333335805
#             ],
#             [
#               -90.08694053633923,
#               40.060770853938635
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240914_160734_98_24b2",
#       "properties": {
#         "acquired": "2024-09-14T16:07:34.987015Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 97,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-09-14T20:30:00Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 101.4,
#         "satellite_id": "24b2",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7577714",
#         "sun_azimuth": 140.2,
#         "sun_elevation": 46.1,
#         "updated": "2024-09-15T03:48:05Z",
#         "view_angle": 4.8,
#         "visible_confidence_percent": 86,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240912_165801_14_24f6",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240912_165801_14_24f6/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240912_165801_14_24f6/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -89.99539142067141,
#               40.117672995835925
#             ],
#             [
#               -90.0476451668639,
#               39.93616346272689
#             ],
#             [
#               -89.65337259973948,
#               39.868391675239785
#             ],
#             [
#               -89.60017173611861,
#               40.049595319840535
#             ],
#             [
#               -89.99539142067141,
#               40.117672995835925
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240912_165801_14_24f6",
#       "properties": {
#         "acquired": "2024-09-12T16:58:01.14355Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 97,
#         "clear_percent": 99,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 1,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-09-12T23:39:10Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 211.8,
#         "satellite_id": "24f6",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7573489",
#         "sun_azimuth": 156.6,
#         "sun_elevation": 51.6,
#         "updated": "2024-09-13T06:31:30Z",
#         "view_angle": 0.1,
#         "visible_confidence_percent": 88,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240908_161007_58_24cc",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240908_161007_58_24cc/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240908_161007_58_24cc/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.07010898556948,
#               40.09380978182171
#             ],
#             [
#               -90.11811602335557,
#               39.925639092783335
#             ],
#             [
#               -89.75297808438344,
#               39.86333932483009
#             ],
#             [
#               -89.70401177506359,
#               40.03115472046151
#             ],
#             [
#               -90.07010898556948,
#               40.09380978182171
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240908_161007_58_24cc",
#       "properties": {
#         "acquired": "2024-09-08T16:10:07.587984Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 67,
#         "clear_percent": 51,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.6,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 49,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-09-12T00:51:33Z",
#         "publishing_stage": "finalized",
#         "quality_category": "standard",
#         "satellite_azimuth": 113.6,
#         "satellite_id": "24cc",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7565133",
#         "sun_azimuth": 138.2,
#         "sun_elevation": 47.9,
#         "updated": "2024-09-12T09:58:21Z",
#         "view_angle": 0.7,
#         "visible_confidence_percent": 66,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20240911_165902_34_24fc",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20240911_165902_34_24fc/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20240911_165902_34_24fc/thumb"
#       },
#       "_permissions": [
#         "assets.basic_analytic_4b:download",
#         "assets.basic_analytic_4b_rpc:download",
#         "assets.basic_analytic_4b_xml:download",
#         "assets.basic_analytic_8b:download",
#         "assets.basic_analytic_8b_xml:download",
#         "assets.basic_udm2:download",
#         "assets.ortho_analytic_4b:download",
#         "assets.ortho_analytic_4b_sr:download",
#         "assets.ortho_analytic_4b_xml:download",
#         "assets.ortho_analytic_8b:download",
#         "assets.ortho_analytic_8b_sr:download",
#         "assets.ortho_analytic_8b_xml:download",
#         "assets.ortho_udm2:download",
#         "assets.ortho_visual:download"
#       ],
#       "assets": [
#         "basic_analytic_4b",
#         "basic_analytic_4b_rpc",
#         "basic_analytic_4b_xml",
#         "basic_analytic_8b",
#         "basic_analytic_8b_xml",
#         "basic_udm2",
#         "ortho_analytic_4b",
#         "ortho_analytic_4b_sr",
#         "ortho_analytic_4b_xml",
#         "ortho_analytic_8b",
#         "ortho_analytic_8b_sr",
#         "ortho_analytic_8b_xml",
#         "ortho_udm2",
#         "ortho_visual"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -90.14149967779092,
#               40.14308247604996
#             ],
#             [
#               -90.19396261855134,
#               39.96186037259474
#             ],
#             [
#               -89.80013908358517,
#               39.8938272320875
#             ],
#             [
#               -89.74674112860964,
#               40.07477705252639
#             ],
#             [
#               -90.14149967779092,
#               40.14308247604996
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20240911_165902_34_24fc",
#       "properties": {
#         "acquired": "2024-09-11T16:59:02.342672Z",
#         "anomalous_pixels": 0,
#         "clear_confidence_percent": 89,
#         "clear_percent": 100,
#         "cloud_cover": 0,
#         "cloud_percent": 0,
#         "ground_control": true,
#         "gsd": 3.9,
#         "heavy_haze_percent": 0,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene",
#         "light_haze_percent": 0,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2024-09-11T20:50:49Z",
#         "publishing_stage": "finalized",
#         "quality_category": "test",
#         "satellite_azimuth": 257.5,
#         "satellite_id": "24fc",
#         "shadow_percent": 0,
#         "snow_ice_percent": 0,
#         "strip_id": "7571382",
#         "sun_azimuth": 156.4,
#         "sun_elevation": 51.9,
#         "updated": "2024-09-12T05:02:35Z",
#         "view_angle": 0.4,
#         "visible_confidence_percent": 75,
#         "visible_percent": 100
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %% [markdown]
# Nice! The response gives us search results for Planet Scope (4 Band) for a specific area.
#
# Let's do another search, this time using the "not" filter we setup earlier:

# %%
# Setup Item Types
item_types = ["PSScene"]

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : not_filter
}

# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(list(geojson.items())[1][1][0])
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250228_144946_47_24d0",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250228_144946_47_24d0/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250228_144946_47_24d0/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -69.56737764301957,
#           7.218596299848224
#         ],
#         [
#           -69.59781758498055,
#           7.064056079058831
#         ],
#         [
#           -69.33714131127648,
#           7.012354286692715
#         ],
#         [
#           -69.30635699648366,
#           7.167825549310224
#         ],
#         [
#           -69.56737764301957,
#           7.218596299848224
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20250228_144946_47_24d0",
#   "properties": {
#     "acquired": "2025-02-28T14:49:46.476704Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 94,
#     "clear_percent": 99,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": false,
#     "gsd": 3.3,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 1,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2025-02-28T20:13:37Z",
#     "publishing_stage": "preview",
#     "quality_category": "test",
#     "satellite_azimuth": 276.8,
#     "satellite_id": "24d0",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "7897614",
#     "sun_azimuth": 115.5,
#     "sun_elevation": 56.2,
#     "updated": "2025-02-28T20:13:37Z",
#     "view_angle": 4.8,
#     "visible_confidence_percent": 78,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }

# %% [markdown]
# Let's take a closer look at our response data:

# %%
# Assign a features variable 
features = geojson["features"]

# Get the number of features present in the response
len(features)
# Out:
# 250

# %%
# Loop over all the features from the response
for f in features:
    # Print the ID for each feature
    p(f["id"])
# Out:
# "20250228_144946_47_24d0"
# "20250228_145341_04_24d0"
# "20250228_144652_44_24d0"
# "20250228_145058_35_24d0"
# "20250228_145523_18_24d0"
# "20250228_145316_44_24d0"
# "20250228_144743_52_24d0"
# "20250228_145509_94_24d0"
# "20250228_145143_75_24d0"
# "20250228_145003_50_24d0"
# "20250228_043159_90_253c"
# "20250228_043056_18_253c"
# "20250228_102716_63_251a"
# "20250228_042308_89_253c"
# "20250228_171551_66_24f6"
# "20250228_040643_87_24c3"
# "20250228_145413_19_24d0"
# "20250228_145011_06_24d0"
# "20250228_145403_73_24d0"
# "20250228_145308_88_24d0"
# "20250228_145026_20_24d0"
# "20250228_144832_70_24d0"
# "20250228_144904_86_24d0"
# "20250228_145204_56_24d0"
# "20250228_043148_10_253c"
# "20250228_043058_54_253c"
# "20250228_153509_46_24ee"
# "20250228_145155_10_24d0"
# "20250228_145035_65_24d0"
# "20250228_042650_51_253c"
# "20250228_144737_84_24d0"
# "20250228_173522_70_24ae"
# "20250228_145350_49_24d0"
# "20250228_145214_02_24d0"
# "20250228_145139_97_24d0"
# "20250228_145043_22_24d0"
# "20250228_144937_01_24d0"
# "20250228_145102_14_24d0"
# "20250228_043110_34_253c"
# "20250228_174148_50_2521"
# "20250228_043100_90_253c"
# "20250228_042938_30_253c"
# "20250228_145249_96_24d0"
# "20250228_042945_38_253c"
# "20250228_043023_14_253c"
# "20250228_043032_58_253c"
# "20250228_152952_07_24ee"
# "20250228_145242_39_24d0"
# "20250228_145039_44_24d0"
# "20250228_144957_82_24d0"
# "20250228_145333_47_24d0"
# "20250228_145231_04_24d0"
# "20250228_042721_19_253c"
# "20250228_145130_51_24d0"
# "20250228_145124_84_24d0"
# "20250228_174208_88_2521"
# "20250228_144317_52_24ae"
# "20250228_133226_90_24c3"
# "20250228_132922_49_24c3"
# "20250228_174006_59_2521"
# "20250228_133109_26_24c3"
# "20250228_144310_78_24ae"
# "20250228_145530_75_24d0"
# "20250228_144751_08_24d0"
# "20250228_133238_55_24c3"
# "20250228_042716_47_253c"
# "20250228_145458_59_24d0"
# "20250228_133146_14_24c3"
# "20250228_145335_36_24d0"
# "20250228_145007_28_24d0"
# "20250228_145151_32_24d0"
# "20250228_133232_73_24c3"
# "20250228_145009_17_24d0"
# "20250228_173301_28_24ae"
# "20250228_154138_71_24ee"
# "20250228_133014_90_24c3"
# "20250228_144811_89_24d0"
# "20250228_043105_62_253c"
# "20250228_134558_23_24d1"
# "20250228_133332_90_24c3"
# "20250228_043103_26_253c"
# "20250228_155511_91_2409"
# "20250228_154130_73_24ee"
# "20250228_043115_06_253c"
# "20250228_133256_02_24c3"
# "20250228_133250_20_24c3"
# "20250228_154132_73_24ee"
# "20250228_132908_91_24c3"
# "20250228_133242_43_24c3"
# "20250228_133307_67_24c3"
# "20250228_133118_96_24c3"
# "20250228_132955_49_24c3"
# "20250228_132928_32_24c3"
# "20250228_132926_38_24c3"
# "20250228_133130_61_24c3"
# "20250228_134207_24_24d1"
# "20250228_134756_73_24d1"
# "20250228_133111_20_24c3"
# "20250228_133103_43_24c3"
# "20250228_132934_14_24c3"
# "20250228_153738_38_24b7"
# "20250228_133311_55_24c3"
# "20250228_133207_49_24c3"
# "20250228_133124_79_24c3"
# "20250228_133157_79_24c3"
# "20250228_133144_20_24c3"
# "20250228_132930_26_24c3"
# "20250228_132903_08_24c3"
# "20250228_133055_67_24c3"
# "20250228_133317_37_24c3"
# "20250228_133209_43_24c3"
# "20250228_133009_08_24c3"
# "20250228_133003_26_24c3"
# "20250228_132957_43_24c3"
# "20250228_134812_80_24d1"
# "20250228_134554_21_24d1"
# "20250228_133215_26_24c3"
# "20250228_153811_11_24ee"
# "20250228_134419_81_24d1"
# "20250228_133138_37_24c3"
# "20250228_132859_20_24c3"
# "20250228_174310_02_2521"
# "20250228_133151_96_24c3"
# "20250228_133032_37_24c3"
# "20250228_132951_61_24c3"
# "20250228_132905_02_24c3"
# "20250228_134417_80_24d1"
# "20250228_133011_02_24c3"
# "20250228_133155_84_24c3"
# "20250228_174829_12_2521"
# "20250228_134411_77_24d1"
# "20250228_134123_06_24d1"
# "20250228_133236_61_24c3"
# "20250228_133230_79_24c3"
# "20250228_132914_73_24c3"
# "20250228_152840_20_24ee"
# "20250228_145153_21_24d0"
# "20250228_133252_14_24c3"
# "20250228_133248_26_24c3"
# "20250228_133107_32_24c3"
# "20250228_132939_96_24c3"
# "20250228_133336_78_24c3"
# "20250228_133303_79_24c3"
# "20250228_133244_37_24c3"
# "20250228_132949_67_24c3"
# "20250228_132920_55_24c3"
# "20250228_133213_32_24c3"
# "20250228_134413_78_24d1"
# "20250228_132918_61_24c3"
# "20250228_132916_67_24c3"
# "20250228_132853_38_24c3"
# "20250228_134125_07_24d1"
# "20250228_133153_90_24c3"
# "20250228_133101_49_24c3"
# "20250228_154140_71_24ee"
# "20250228_134546_17_24d1"
# "20250228_133122_85_24c3"
# "20250228_133049_85_24c3"
# "20250228_133047_90_24c3"
# "20250228_174431_55_2521"
# "20250228_133254_08_24c3"
# "20250228_132932_20_24c3"
# "20250228_133038_20_24c3"
# "20250228_133026_55_24c3"
# "20250228_133240_49_24c3"
# "20250228_133142_26_24c3"
# "20250228_133126_73_24c3"
# "20250228_133323_20_24c3"
# "20250228_133203_61_24c3"
# "20250228_133117_02_24c3"
# "20250228_133059_55_24c3"
# "20250228_133024_61_24c3"
# "20250228_175417_39_24c4"
# "20250228_133113_14_24c3"
# "20250228_133001_32_24c3"
# "20250228_134754_72_24d1"
# "20250228_134550_19_24d1"
# "20250228_132924_43_24c3"
# "20250228_133128_67_24c3"
# "20250228_153815_10_24ee"
# "20250228_153723_20_24ee"
# "20250228_133148_08_24c3"
# "20250228_132906_96_24c3"
# "20250228_175403_67_24c4"
# "20250228_144328_74_24ae"
# "20250228_132851_43_24c3"
# "20250228_132841_73_24c3"
# "20250228_134814_81_24d1"
# "20250228_133259_90_24c3"
# "20250228_133246_31_24c3"
# "20250228_134810_79_24d1"
# "20250228_133330_96_24c3"
# "20250228_133221_08_24c3"
# "20250228_133136_43_24c3"
# "20250228_133028_49_24c3"
# "20250228_133018_79_24c3"
# "20250228_132910_85_24c3"
# "20250228_133305_73_24c3"
# "20250228_133257_96_24c3"
# "20250228_134127_07_24d1"
# "20250228_133309_61_24c3"
# "20250228_133228_84_24c3"
# "20250228_133132_55_24c3"
# "20250228_134758_74_24d1"
# "20250228_133217_20_24c3"
# "20250228_154604_32_24c6"
# "20250228_134552_20_24d1"
# "20250228_134431_86_24d1"
# "20250228_175425_12_24c4"
# "20250228_133224_96_24c3"
# "20250228_133219_14_24c3"
# "20250228_175747_93_24c4"
# "20250228_175411_40_24c4"
# "20250228_133327_08_24c3"
# "20250228_133301_84_24c3"
# "20250228_133053_73_24c3"
# "20250228_175528_92_24c4"
# "20250228_133205_55_24c3"
# "20250228_133201_67_24c3"
# "20250228_133051_79_24c3"
# "20250228_134542_16_24d1"
# "20250228_133334_84_24c3"
# "20250228_133057_61_24c3"
# "20250228_175517_32_24c4"
# "20250228_134211_26_24d1"
# "20250228_133325_14_24c3"
# "20250228_133159_73_24c3"
# "20250228_132849_49_24c3"
# "20250228_175519_25_24c4"
# "20250228_133034_32_24c3"
# "20250228_132901_14_24c3"
# "20250228_155451_49_2409"
# "20250228_153740_34_24b7"
# "20250228_133223_02_24c3"
# "20250228_132912_79_24c3"
# "20250228_133329_02_24c3"
# "20250228_133120_90_24c3"
# "20250228_133105_37_24c3"
# "20250228_155815_70_2409"
# "20250228_133042_08_24c3"
# "20250228_175427_05_24c4"
# "20250228_175409_47_24c4"
# "20250228_155817_97_2409"
# "20250228_134209_25_24d1"
# "20250228_133140_32_24c3"
# "20250228_175350_14_24c4"
# "20250228_134556_22_24d1"
# "20250228_133338_73_24c3"
# "20250228_133150_02_24c3"
# "20250228_175440_59_24c4"

# %%
# Print the first feature
p(features[0])
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene/items/20250228_144946_47_24d0",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene/items/20250228_144946_47_24d0/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene/items/20250228_144946_47_24d0/thumb"
#   },
#   "_permissions": [
#     "assets.basic_analytic_4b:download",
#     "assets.basic_analytic_4b_rpc:download",
#     "assets.basic_analytic_4b_xml:download",
#     "assets.basic_analytic_8b:download",
#     "assets.basic_analytic_8b_xml:download",
#     "assets.basic_udm2:download",
#     "assets.ortho_analytic_4b:download",
#     "assets.ortho_analytic_4b_xml:download",
#     "assets.ortho_analytic_8b:download",
#     "assets.ortho_analytic_8b_xml:download",
#     "assets.ortho_udm2:download",
#     "assets.ortho_visual:download"
#   ],
#   "assets": [
#     "basic_analytic_4b",
#     "basic_analytic_4b_rpc",
#     "basic_analytic_4b_xml",
#     "basic_analytic_8b",
#     "basic_analytic_8b_xml",
#     "basic_udm2",
#     "ortho_analytic_4b",
#     "ortho_analytic_4b_xml",
#     "ortho_analytic_8b",
#     "ortho_analytic_8b_xml",
#     "ortho_udm2",
#     "ortho_visual"
#   ],
#   "geometry": {
#     "coordinates": [
#       [
#         [
#           -69.56737764301957,
#           7.218596299848224
#         ],
#         [
#           -69.59781758498055,
#           7.064056079058831
#         ],
#         [
#           -69.33714131127648,
#           7.012354286692715
#         ],
#         [
#           -69.30635699648366,
#           7.167825549310224
#         ],
#         [
#           -69.56737764301957,
#           7.218596299848224
#         ]
#       ]
#     ],
#     "type": "Polygon"
#   },
#   "id": "20250228_144946_47_24d0",
#   "properties": {
#     "acquired": "2025-02-28T14:49:46.476704Z",
#     "anomalous_pixels": 0,
#     "clear_confidence_percent": 94,
#     "clear_percent": 99,
#     "cloud_cover": 0,
#     "cloud_percent": 0,
#     "ground_control": false,
#     "gsd": 3.3,
#     "heavy_haze_percent": 0,
#     "instrument": "PSB.SD",
#     "item_type": "PSScene",
#     "light_haze_percent": 1,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2025-02-28T20:13:37Z",
#     "publishing_stage": "preview",
#     "quality_category": "test",
#     "satellite_azimuth": 276.8,
#     "satellite_id": "24d0",
#     "shadow_percent": 0,
#     "snow_ice_percent": 0,
#     "strip_id": "7897614",
#     "sun_azimuth": 115.5,
#     "sun_elevation": 56.2,
#     "updated": "2025-02-28T20:13:37Z",
#     "view_angle": 4.8,
#     "visible_confidence_percent": 78,
#     "visible_percent": 100
#   },
#   "type": "Feature"
# }

# %% [markdown]
# What happens when there are A LOT of results?
#
# When the number of matching items exceeds 250, the results are delivered in pages. Let's perform a search query that should return a large number of results:

# %%
# Setup a GeoJSON polygon for our geometry filter
geom = {
    "type": "Polygon",
    "coordinates": [
      [
        [
          -125.29632568359376,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          48.37084770238366
        ]
      ]
    ]
  }

# Setup the geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# %%
# Print the response "_links" property
p(geojson["_links"])
# Out:
# {
#   "_first": "https://api.planet.com/data/v1/searches/9e4dfb9474154708bd36ab5032159942/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/9e4dfb9474154708bd36ab5032159942/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDI1LTAyLTIxVDAwOjA1OjUzLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjUwMjIwXzE4NTcwN182Nl8yNGIzIiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/9e4dfb9474154708bd36ab5032159942/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
# }

# %%
# Assign the "_links" -> "_next" property (link to next page of results) to a variable 
next_url = geojson["_links"]["_next"]

# Print the link to the next page of results
print(next_url)
# Out:
# https://api.planet.com/data/v1/searches/9e4dfb9474154708bd36ab5032159942/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDI1LTAyLTIxVDAwOjA1OjUzLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjUwMjIwXzE4NTcwN182Nl8yNGIzIiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319

# %% [markdown]
# The page size can be set with a `_page_size` parameter in the request:

# %%
# Send the POST request to the API quick search endpoint with a page size of 9
res = session.post(quick_url, json=request, params={"_page_size" : 9})

# Assign the response to a variable
geojson = res.json()

# Get the number of features present in the response
len(geojson["features"])
# Out:
# 9

# %% [markdown]
# ### Mapping Footprints Example
#
# The [`geojsonio`](https://pypi.python.org/pypi/geojsonio/) module can be used to map GeoJSON files and is therefore compatible with the output from Planet Data API searches.
#
# Make sure you've got the module installed and then let's use it to show our resuls on a map:

# %%
# Assign the url variable to display the geojsonio map
url = geojsonio.display(res.text)

# %% [markdown]
# We can now iterate through the pages of results.

# %%
# Assign the next_url variable to the next page of results from the response (Setup the next page of results)
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Setup the next page of results
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %% [markdown]
# Cool huh? Now that we know how to search and find items we are interested in, let's try activating and downloading some assets.

# %% [markdown]
# ## Assets & Permissions
#
# Assets may be imagery files, image masks, metadata files or some other file type that might be associated with the item.
#
# The `_permissions` element in each feature contains a list of assets that the user has access to.

# %% [markdown]
# Let's pick the first item out of our search result to work with, and then see what the permissions are for that item:

# %%
# Assign a variable to the search result features (items)
features = geojson["features"]

# Get the first result's feature
feature = features[0]

# Print the ID
p(feature["id"])

# Print the permissions
p(feature["_permissions"])
# Out:
# "20250227_193237_93_24d5"
# [
#   "assets.basic_analytic_4b:download",
#   "assets.basic_analytic_4b_rpc:download",
#   "assets.basic_analytic_4b_xml:download",
#   "assets.basic_analytic_8b:download",
#   "assets.basic_analytic_8b_xml:download",
#   "assets.basic_udm2:download",
#   "assets.ortho_analytic_4b:download",
#   "assets.ortho_analytic_4b_sr:download",
#   "assets.ortho_analytic_4b_xml:download",
#   "assets.ortho_analytic_8b:download",
#   "assets.ortho_analytic_8b_sr:download",
#   "assets.ortho_analytic_8b_xml:download",
#   "assets.ortho_udm2:download",
#   "assets.ortho_visual:download"
# ]

# %% [markdown]
# Each item has an `assets` endpoint in the API that lists all of its assets. Let's get a list of available assets for our item:

# %%
# Get the assets link for the item
assets_url = feature["_links"]["assets"]

# Print the assets link
print(assets_url)
# Out:
# https://api.planet.com/data/v1/item-types/PSScene/items/20250227_193237_93_24d5/assets/

# %%
# Send a GET request to the assets url for the item (Get the list of available assets for the item)
res = session.get(assets_url)

# Assign a variable to the response
assets = res.json()

# %%
# Print the asset types that are available
print(assets.keys())
# Out:
# dict_keys(['basic_analytic_4b', 'basic_analytic_4b_rpc', 'basic_analytic_4b_xml', 'basic_analytic_8b', 'basic_analytic_8b_xml', 'basic_udm2', 'ortho_analytic_4b', 'ortho_analytic_4b_sr', 'ortho_analytic_4b_xml', 'ortho_analytic_8b', 'ortho_analytic_8b_sr', 'ortho_analytic_8b_xml', 'ortho_udm2', 'ortho_visual'])

# %% [markdown]
# We can see that most items have several assets available. Let's check out the "basic_analytic_4b" asset for this item. This is the 4-band analytic asset for the PSScene item.

# %%
# Assign a variable to the visual asset from the item's assets
basic_analytic4b = assets["basic_analytic_4b"]

# Print the visual asset data
p(basic_analytic4b)
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjUwMjI3XzE5MzIzN185M18yNGQ1IiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjUwMjI3XzE5MzIzN185M18yNGQ1IiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_4b"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "expires_at": "2025-02-28T21:14:10.609050",
#   "location": "https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..kB8fLWdFZD8J7oNSaEc5hZZMqoZ9tzPgozZDVOjcwphoDdB9nqBMszBbxLdKTVHwAaxiCEs7a82UMWX8pyisCA",
#   "md5_digest": "614cc95217fa32aabc0f5cb1bbcab4e9",
#   "status": "active",
#   "type": "basic_analytic_4b"
# }

# %% [markdown]
# ### Activating Assets
#
# Before an asset is available for download, it must be **activated**.
#
# You can activate an asset by sending a *POST* or *GET* request to the asset's **"activation link"**.
#
# The activation usually takes a little bit of time, but hey, I'm sure by now you have some ideas on how to automate your workflow. Go robots!

# %%
# Setup the activation url for a particular asset (in this case the basic_analytic_4b asset)
activation_url = basic_analytic4b["_links"]["activate"]

# Send a request to the activation url to activate the item
res = session.get(activation_url)

# Print the response from the activation request
p(res.status_code)
# Out:
# 204

# %% [markdown]
# #### Activation Response Codes
#
# After hitting an activation url, you should get a response code back from the API:
#
# * **`202`** - The request has been accepted and the activation will begin shortly.
# * **`204`** - The asset is already active and no further action is needed.
# * **`401`** - The user does not have permissions to download this file.

# %% [markdown]
# After requesting to activate an asset, let's do another request to see if the assset's status has changed. This may take some time.

# %%
asset_activated = False

while asset_activated == False:
    # Send a request to the item's assets url
    res = session.get(assets_url)

    # Assign a variable to the item's assets url response
    assets = res.json()

    # Assign a variable to the basic_analytic_4b asset from the response
    visual = assets["basic_analytic_4b"]

    asset_status = basic_analytic4b["status"]
    # print(basic_analytic4b)
    print(asset_status)
    
    # If asset is already active, we are done
    if asset_status == 'active':
        asset_activated = True
        print("Asset is active and ready to download")

# Print the ps4b_analytic asset data    
p(basic_analytic4b)
# Out:
# active
# Asset is active and ready to download
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjUwMjI3XzE5MzIzN185M18yNGQ1IiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjUwMjI3XzE5MzIzN185M18yNGQ1IiwgImMiOiAiUFNTY2VuZSIsICJ0IjogImJhc2ljX2FuYWx5dGljXzRiIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/basic_analytic_4b"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "expires_at": "2025-02-28T21:14:10.609050",
#   "location": "https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..kB8fLWdFZD8J7oNSaEc5hZZMqoZ9tzPgozZDVOjcwphoDdB9nqBMszBbxLdKTVHwAaxiCEs7a82UMWX8pyisCA",
#   "md5_digest": "614cc95217fa32aabc0f5cb1bbcab4e9",
#   "status": "active",
#   "type": "basic_analytic_4b"
# }

# %% [markdown]
# #### Activation Status
#
# An asset may have a `status` of `inactive`, `activating` or `active`.
#
# Once an asset is active, the response will contain a `location`. We'll use the `location` to download the asset!
#
# Below, we are polling the API until the item is activated. This may take awhile.

# %% [markdown]
# ### Downloading Assets
#
# The asset's `location` property points asset file for use to download. Are you ready to download the asset? Let's do it!

# %%
# Assign a variable to the visual asset's location endpoint
location_url = basic_analytic4b["location"]

# Print the location endpoint
print(location_url)
# Out:
# https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..kB8fLWdFZD8J7oNSaEc5hZZMqoZ9tzPgozZDVOjcwphoDdB9nqBMszBbxLdKTVHwAaxiCEs7a82UMWX8pyisCA

# %% [markdown]
# There's the location url! You could click on it to open it in a browser and download the file... but why not let your code do it?
#
# Let's write a small helper function to download asset files:

# %%
# Create a function to download asset files
# Parameters: 
# - url (the location url)
# - filename (the filename to save it as. defaults to whatever the file is called originally)

def pl_download(url, filename=None):
    
    # Send a GET request to the provided location url, using your API Key for authentication
    res = requests.get(url, stream=True, auth=(API_KEY, ""))
    # If no filename argument is given
    if not filename:
        # Construct a filename from the API response
        if "content-disposition" in res.headers:
            filename = res.headers["content-disposition"].split("filename=")[-1].strip("'\"")
        # Construct a filename from the location url
        else:
            filename = url.split("=")[1][:10]
    # Save the file
    with open('output/' + filename, "wb") as f:
        for chunk in res.iter_content(chunk_size=1024):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush()

    return filename

# %%
# Download the file from an activated asset's location url
pl_download(location_url)
# Out:
# '20250227_193237_93_24d5_1B_AnalyticMS.tif'

# %% [markdown]
# **High Five!** You should now be downloading your very own GeoTIFF! We can't wait to see what you'll do with it!

# %% [markdown]
# ### Rate Limits
#
# ---
#
# Now that you know how to download assets, you should probably keep some of the API **rate limits** in mind:
#
# * For most endpoints, the rate limit is 10 requests per second, per API key.
# * For activation endpoints, the rate limit is 5 requests per second, per API key.
# * For download endpoints, the rate limit is 15 requests per second, per API key.
#
# If you're writing to code to automate accessing the API, you should account for `429` responses and handle retries after a *backoff period*.

# %% [markdown]
# ## Saved Searches
#
# ---
#
# The `/searches` endpoint lets you created saved searches that can be reused.
#
# To view your saved searches, visit the [`searches/?search_type=saved`](https://api.planet.com/data/v1/searches/?search_type=saved) endpoint.
#
# Finally, let's create a saved search:

# %%
# Setup the saved searches endpoint url
searches_url = "{}/searches".format(URL)

# %%
# Setup the request, specifying a name for the saved search, along with the usual search item_types and filter.
request = {
    "name" : "Vancouver Island",
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send a POST request to the saved searches endpoint (Create the saved search)
res = session.post(searches_url, json=request)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/0b56e34409ec47fba0f5fe0264ea5888",
#     "results": "https://api.planet.com/data/v1/searches/0b56e34409ec47fba0f5fe0264ea5888/results"
#   },
#   "created": "2025-02-28T20:24:25.047190Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "relation": null,
#     "type": "GeometryFilter"
#   },
#   "id": "0b56e34409ec47fba0f5fe0264ea5888",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2025-02-28T20:24:25.047190Z"
# }

# %% [markdown]
# Now that we created a saved search, let's get a list of our saved searches:

# %%
# Send a GET request to the saved searches endpoint with the saved search type parameter (Get saved searches)
res = session.get(searches_url, params={"search_type" : "saved"})

# Assign a variable to the searches property in the saved searches response
searches = res.json()["searches"]
print(searches[2])#['name'])
print(len(searches))

# Loop through the searches
for search in searches:
    # Print the ID, Created Time, and Name for each saved search
    print("id: {} created: {} name: {}".format(search["id"], search["created"], search['name']))
# Out:
# {'__daily_email_enabled': False, '_links': {'_self': 'https://api.planet.com/data/v1/searches/c6c3307e29a84530b800781253ef3394', 'results': 'https://api.planet.com/data/v1/searches/c6c3307e29a84530b800781253ef3394/results'}, 'created': '2025-02-27T19:59:58.356928Z', 'filter': {'config': [{'config': {'coordinates': [[[-125.787619497603, 49.0739489964676], [-125.787619497603, 48.9910630452092], [-125.665851322093, 48.9910630452092], [-125.665851322093, 49.0739489964676], [-125.787619497603, 49.0739489964676]]], 'type': 'Polygon'}, 'field_name': 'geometry', 'relation': None, 'type': 'GeometryFilter'}, {'config': {'gt': 60.0}, 'field_name': 'clear_percent', 'type': 'RangeFilter'}, {'config': ['ortho_analytic_4b'], 'type': 'AssetFilter'}, {'config': {'gt': '2023-01-01T00:00:00Z', 'lt': '2024-12-31T00:00:00Z'}, 'field_name': 'acquired', 'type': 'DateRangeFilter'}], 'type': 'AndFilter'}, 'id': 'c6c3307e29a84530b800781253ef3394', 'item_types': ['PSScene'], 'last_executed': '2025-02-27T20:00:06.867421Z', 'name': 'tofino_refined', 'search_type': 'saved', 'updated': '2025-02-27T20:00:06.867695Z'}
# 5
# id: 0b56e34409ec47fba0f5fe0264ea5888 created: 2025-02-28T20:24:25.047190Z name: Vancouver Island
# id: b8668d520a594916bb9beb4bf458c92c created: 2025-02-27T20:16:56.038718Z name: tofino_refined
# id: c6c3307e29a84530b800781253ef3394 created: 2025-02-27T19:59:58.356928Z name: tofino_refined
# id: 269b89cf0cef4346a40b4c5d27ec1d2a created: 2024-10-17T18:53:31.014582Z name: Pat Bay Good
# id: bd63ff337b4243cd91e6b17838e41322 created: 2024-10-17T18:52:47.130482Z name: Pat Bay

# %% [markdown]
# Ok, now let's check out the results from a particular saved search:

# %%
# Setup the saved search url, using the first saved search in the list
saved_url = "{}/{}".format(searches_url, searches[0]["id"])

# Print the saved search url
p(saved_url)

# Setup the saved search's results url
results_url = "{}/results".format(saved_url)

# Print the saved search's results url
p(results_url)
# Out:
# "https://api.planet.com/data/v1/searches/0b56e34409ec47fba0f5fe0264ea5888"
# "https://api.planet.com/data/v1/searches/0b56e34409ec47fba0f5fe0264ea5888/results"

# %%
# Send a GET request to the saved search url (Get the saved search data)
res = session.get(saved_url)

# Print the response
p(res.json())
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/0b56e34409ec47fba0f5fe0264ea5888",
#     "results": "https://api.planet.com/data/v1/searches/0b56e34409ec47fba0f5fe0264ea5888/results"
#   },
#   "created": "2025-02-28T20:24:25.047190Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "relation": null,
#     "type": "GeometryFilter"
#   },
#   "id": "0b56e34409ec47fba0f5fe0264ea5888",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2025-02-28T20:24:25.047190Z"
# }

# %%
# Send a GET request to the saved search results url (Get the saved search results)
results = session.get(results_url).json()

# Print the number of features in the saved search
print(len(results["features"]))

# Print the first feature in the saved search
print(results["features"][0])
# Out:
# 250
# {'_links': {'_self': 'https://api.planet.com/data/v1/item-types/PSScene/items/20250227_185805_67_24bf', 'assets': 'https://api.planet.com/data/v1/item-types/PSScene/items/20250227_185805_67_24bf/assets/', 'thumbnail': 'https://tiles.planet.com/data/v1/item-types/PSScene/items/20250227_185805_67_24bf/thumb'}, '_permissions': ['assets.basic_analytic_4b:download', 'assets.basic_analytic_4b_rpc:download', 'assets.basic_analytic_4b_xml:download', 'assets.basic_analytic_8b:download', 'assets.basic_analytic_8b_xml:download', 'assets.basic_udm2:download', 'assets.ortho_analytic_4b:download', 'assets.ortho_analytic_4b_sr:download', 'assets.ortho_analytic_4b_xml:download', 'assets.ortho_analytic_8b:download', 'assets.ortho_analytic_8b_sr:download', 'assets.ortho_analytic_8b_xml:download', 'assets.ortho_udm2:download', 'assets.ortho_visual:download'], 'assets': ['basic_analytic_4b', 'basic_analytic_4b_rpc', 'basic_analytic_4b_xml', 'basic_analytic_8b', 'basic_analytic_8b_xml', 'basic_udm2', 'ortho_analytic_4b', 'ortho_analytic_4b_sr', 'ortho_analytic_4b_xml', 'ortho_analytic_8b', 'ortho_analytic_8b_sr', 'ortho_analytic_8b_xml', 'ortho_udm2', 'ortho_visual'], 'geometry': {'coordinates': [[[-125.46206202269984, 48.731837407150266], [-125.51729164733328, 48.57808541792863], [-125.13060119824902, 48.51588457971784], [-125.07413298635137, 48.66954599204514], [-125.46206202269984, 48.731837407150266]]], 'type': 'Polygon'}, 'id': '20250227_185805_67_24bf', 'properties': {'acquired': '2025-02-27T18:58:05.671842Z', 'anomalous_pixels': 0, 'clear_confidence_percent': 98, 'clear_percent': 0, 'cloud_cover': 1, 'cloud_percent': 100, 'ground_control': False, 'gsd': 3.3, 'heavy_haze_percent': 0, 'instrument': 'PSB.SD', 'item_type': 'PSScene', 'light_haze_percent': 0, 'pixel_resolution': 3, 'provider': 'planetscope', 'published': '2025-02-28T09:39:11Z', 'publishing_stage': 'preview', 'quality_category': 'test', 'satellite_azimuth': 264.2, 'satellite_id': '24bf', 'shadow_percent': 0, 'snow_ice_percent': 0, 'strip_id': '7895881', 'sun_azimuth': 152.5, 'sun_elevation': 29.6, 'updated': '2025-02-28T11:31:46Z', 'view_angle': 0.6, 'visible_confidence_percent': 49, 'visible_percent': 0}, 'type': 'Feature'}

# %% [markdown]
# A saved search can also be updated by senidng a **`PUT`** request with a changed search definition back to the API.
#
# Did you know that saved searches can also send you a daily email to alert you to when new items are added to the search resutlts? Oh yeah!

# %%
# Assign a variable to the saved search response
search = res.json()

# Print the saved search
p(search)
# Out:
# {
#   "__daily_email_enabled": false,
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/searches/0b56e34409ec47fba0f5fe0264ea5888",
#     "results": "https://api.planet.com/data/v1/searches/0b56e34409ec47fba0f5fe0264ea5888/results"
#   },
#   "created": "2025-02-28T20:24:25.047190Z",
#   "filter": {
#     "config": {
#       "coordinates": [
#         [
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             49.335861591104106
#           ],
#           [
#             -123.2391357421875,
#             48.37084770238366
#           ],
#           [
#             -125.29632568359376,
#             48.37084770238366
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "field_name": "geometry",
#     "relation": null,
#     "type": "GeometryFilter"
#   },
#   "id": "0b56e34409ec47fba0f5fe0264ea5888",
#   "item_types": [
#     "PSScene"
#   ],
#   "last_executed": null,
#   "name": "Vancouver Island",
#   "search_type": "saved",
#   "updated": "2025-02-28T20:24:25.047190Z"
# }

# %%
# Change the saved search name to "South Vancouver Island"
search["name"] = "South Vancouver Island"

# Set the daily email enabled to true (Get email alerts when new items show up in this search)
search["__daily_email_enabled"] = True

# Send a PUT request to the saved search endpoint (Update the saved search)
res = session.put(saved_url, json=search)

# The response status code
res.status_code
# Out:
# 400

# %% [markdown]
# ## Conclusion
#
# You made it! You should now be able to use the Planet API to find items and assets by searching, get stats and save searches, and activate and download assets using Python code!
#
# Don't forget to visit the [Planet API Reference Docs](https://developers.planet.com/docs/apis/).
